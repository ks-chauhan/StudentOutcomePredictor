# %% [markdown]
# <a href="https://colab.research.google.com/github/ks-chauhan/StudentOutcomePredictor/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Drive mount to Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, f1_score, precision_score, recall_score, confusion_matrix
from imblearn.over_sampling import SMOTE
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader
from tqdm.auto import tqdm

# %%
# Loading dataset
data_path = "/content/drive/MyDrive/Gradious_Assignments/Mini_Project_ML/gradious_ML_mini_project.csv"
df = pd.read_csv(data_path)

# %%
pd.set_option('display.max_columns', None)

# %%
# The values the given target can have
df['Outcome'].unique()
# Out:
# array(['Dropout', 'Graduate', 'Enrolled'], dtype=object)

# %%
df.head()
# Out:
#    Marital_Status_Code  Application_Method  Application_Sequence  Program_ID  \
# 0                    1                  17                     5         171
# 1                    1                  15                     1        9254
# 2                    1                   1                     5        9070
# 3                    1                  17                     2        9773
# 4                    2                  39                     1        8014
#
#    Attendance_Type  Prior_Qualification_Code  Prior_Qualification_Score  \
# 0                1                         1                      122.0
# 1                1                         1                      160.0
# 2                1                         1                      122.0
# 3                1                         1                      122.0
# 4                0                         1                      100.0
#
# ...

# %%
# No null values
df.isna().sum()
# Out:
# Marital_Status_Code            0
# Application_Method             0
# Application_Sequence           0
# Program_ID                     0
# Attendance_Type                0
# Prior_Qualification_Code       0
# Prior_Qualification_Score      0
# Nationality_Code               0
# Mother's_Education_Level       0
# Father's_Education_Level       0
# Mother's_Job_Category          0
# Father's_Job_Category          0
# Admission_Score                0
# Student_Displacement_Flag      0
# Special_Educational_Needs      0
# Outstanding_Debts_Flag         0
# Tuition_Fees_UpToDate_Flag     0
# Gender_Code                    0
# Scholarship_Recipient_Flag     0
# Enrollment_Age                 0
# International_Status           0
# Credits_1st_Semester           0
# Enrolled_1st_Semester          0
# Evaluations_1st_Semester       0
# Passed_1st_Semester            0
# Grade_1st_Semester             0
# No_Evaluations_1st_Semester    0
# Credits_2nd_Semester           0
# ...
